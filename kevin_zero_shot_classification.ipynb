# %%
# load test dataset, retrieve this from the .csv file. CHANGE PATH!!!!!!!!!!!!!!!!!!

import pandas as pd

test_frame = pd.read_csv('fpb_test.csv')

text_col = 'text_column'  # text
label_col = 'label_column' # label
source_col = '' # sure why not
unique_labels = df[label_col].unique().tolist()

print(f"Loaded {len(df)} rows.")
print(f"Labels found: {unique_labels}")

display(df.test_frame())
